# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("ExecutionLog.csv")

# %%
df = df[df['type'].astype("string").str.contains("AES")]
df_pivot = pd.pivot_table(
    df,
    index="type",
    columns="keyLen",
    values=["time"],
)
# Plot a bar chart using the DF
ax = df_pivot.plot(kind="bar")
# Get a Matplotlib figure from the axes object for formatting purposes
fig = ax.get_figure()
ax.set_yscale("log", basey=2)
# Change the plot dimensions (width, height)
fig.set_size_inches(7, 6)
plt.xticks(rotation=0)

plt.show()
# Out:
# <ipython-input-7-18455a10c06f>:12: MatplotlibDeprecationWarning: The 'basey' parameter of __init__() has been renamed 'base' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   ax.set_yscale("log", basey=2)
